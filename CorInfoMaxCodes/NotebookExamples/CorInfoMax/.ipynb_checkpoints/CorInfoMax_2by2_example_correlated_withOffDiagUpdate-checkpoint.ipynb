# %%
import sys
sys.path.append("../../src")

import numpy as np
from scipy.stats import ortho_group
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from CorInfoMaxBSS import OnlineCorInfoMax2by2
from visualization_utils import display_matrix, subplot_1D_signals
from bss_utils import generate_correlated_copula_sources, addWGN

# %% [markdown]
# # Generate Sources and Mix Them (2 by 2 case)

# %%
np.random.seed(0)
N = 100000
NumberofSources = 2
NumberofMixtures = 2

S = generate_correlated_copula_sources(rho=0.4, df=4, n_sources=2, size_sources=N, decreasing_correlation=True)
S = 2 * S - 1 # Make the domain [-1, 1]
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures, NumberofSources) # Random Gaussian mixing matrix
# A = ortho_group.rvs(dim=2) # Random orthogonal mixing matrix
X_noNoise = np.dot(A, S)

SNR = 30
X = addWGN(X_noNoise, SNR)

SNRinp = 10 * np.log10(
    np.sum(np.mean(X_noNoise ** 2, axis=1))
    / np.sum(np.mean((X_noNoise - X)**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.373 & \\
#  0.373 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.637 & 0.925 & \\
#  -0.757 & 0.492 & \\
# \end{bmatrix}$
# Input SNR is : 29.991041495633517

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(8, 4), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(8, 4), colorcode=None
)

# %%
lambday = 1 - 1e-1 / 10
lambdae = 1 - 1e-1 / 10
# Inverse output covariance
By = 1. * np.eye(2)
epsilon = 1e-3
update_off_diagonal_By = True

debug_iteration_point = 25000
model = OnlineCorInfoMax2by2(
    muW=30 * 1e-3,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    epsilon = epsilon,
    neural_OUTPUT_COMP_TOL=1e-6,
    update_off_diagonal_By = update_off_diagonal_By,
    ## The below arguments are used only for debugging
    set_ground_truth=True,
    S=S,
    A=A,
)

# %%
model.fit_batch_antisparse(
    X=X,
    n_epochs=1,
    neural_dynamic_iterations=500,
    plot_in_jupyter=True,
    neural_lr_start=0.9,
    neural_lr_stop=0.001,
    debug_iteration_point=debug_iteration_point,
    shuffle=True,
)
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 100000/100000 [00:27<00:00, 3613.46it/s]

# %%
Wf = model.compute_overall_mapping(return_mapping=True)
Y = Wf @ X
Y_ = model.signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(model.snr_jit(S, Y_)))

SINR = 10 * np.log10(model.CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [29.3752274  26.40874595]
#
# Overall SINR : 27.63851004555483

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(8, 4),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(8, 4), colorcode=None
)

# %%
np.diag(np.diag(model.By))
# Out:
# array([[2.88759559, 0.        ],
#        [0.        , 3.0256443 ]])

# %%
model.By
# Out:
# array([[ 2.88759559, -1.05223045],
#        [-1.05223045,  3.0256443 ]])

# %%
model.game / model.epsilon
# Out:
# 10.101010101010111

# %%
np.eye(*model.By.shape)
# Out:
# array([[1., 0.],
#        [0., 1.]])

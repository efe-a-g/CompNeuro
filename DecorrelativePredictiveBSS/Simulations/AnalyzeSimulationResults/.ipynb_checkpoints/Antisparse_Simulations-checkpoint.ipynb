# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # 10 by 5 Mixing with Correlated Sources Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_correlated_antisparse_10by5_results.pkl")
df_predictiveBSS.tail()
# Out:
#                     Model  seed  rho       SINR  \
# 1645  PredictiveDecorrBSS  2900  0.5  15.988121
# 1646        CorInfoMaxBSS  2900  0.5  22.653369
# 1647          ICA_InfoMax  2900  0.5   1.401881
# 1648              LDMIBSS  2900  0.5  29.016550
# 1649               BSMBSS  2900  0.5   7.825359
#
#                                                     SNR  SNRinp  \
# 1645  [[14.982330104149638, 17.00595048912016, 16.09...      30
# 1646  [[20.9411742789251, 23.680648285373252, 22.638...      30
# 1647  [[0.7480883845801044, 0.736956611572501, 13.32...      30
# 1648  [[28.473794655650337, 29.17135544154803, 28.03...      30
# 1649  [[7.687452501028238, 7.93548383811287, 7.87258...      30
#
#       execution_time
# 1645       13.721070
# 1646        4.953862
# 1647        5.879516
# 1648        9.594000
# 1649        3.327069

# %%
summary_df = create_summary_table(df_predictiveBSS)
# summary_df

# %%
plot_title = "Correlated Antisparse Source Separation - mSNR Results"
bss_plot = plot_snr_performance(summary_df, title = plot_title)
plt.savefig('Figures/Antisparse_Correlated_Comparison.pdf', format='pdf', bbox_inches = 'tight')
bss_plot.show()

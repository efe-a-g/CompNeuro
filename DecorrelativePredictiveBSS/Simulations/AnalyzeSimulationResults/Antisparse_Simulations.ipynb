# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # 10 by 5 Mixing with Correlated Sources Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_correlated_antisparse_10by5_results.pkl")
df_predictiveBSS
# Out:
#                           Model  seed  rho       SINR  \
# 0           PredictiveDecorrBSS     0  0.0  26.818387
# 1     PredictiveDecorrBSSSimple     0  0.0   4.033262
# 2                 CorInfoMaxBSS     0  0.0  25.135626
# 3                   ICA_InfoMax     0  0.0  29.914584
# 4                       LDMIBSS     0  0.0  29.892748
# ...                         ...   ...  ...        ...
# 1975  PredictiveDecorrBSSSimple  2900  0.5   6.536913
# 1976              CorInfoMaxBSS  2900  0.5  22.546660
# 1977                ICA_InfoMax  2900  0.5   1.378488
# 1978                    LDMIBSS  2900  0.5  29.364337
# 1979                     BSMBSS  2900  0.5   7.828772
#
#                                                     SNR  SNRinp  \
# 0     [[26.291249002514935, 30.16830670441017, 26.03...      30
# 1     [[26.28898053534953, 30.41555545706158, 26.040...      30
# 2     [[25.904404962879664, 29.83177213745988, 20.78...      30
# 3     [[29.10667221906639, 31.78471055439449, 27.551...      30
# 4     [[29.035651154567876, 32.10724731987666, 27.47...      30
# ...                                                 ...     ...
# 1975  [[23.094087047774295, 23.61103431840464, 0.993...      30
# 1976  [[21.7652122782083, 21.32654489391557, 23.1367...      30
# 1977  [[0.7129674559268189, 0.7358915563123607, 13.2...      30
# 1978  [[28.709661190433494, 29.85069510145724, 28.45...      30
# 1979  [[7.787554832320911, 7.90191141836498, 7.89920...      30
#
#       execution_time
# 0           9.140350
# 1           5.666424
# 2           1.861441
# 3           2.583226
# 4           5.344979
# ...              ...
# 1975        5.403463
# 1976        1.715541
# 1977        2.501491
# 1978        3.870974
# 1979        1.189662
#
# [1980 rows x 7 columns]

# %%
summary_df = create_summary_table(df_predictiveBSS)
# summary_df

# %%
plot_title = "Correlated Antisparse Source Separation - mSNR Results"
bss_plot = plot_snr_performance(summary_df, title = plot_title)
plt.savefig('Figures/Antisparse_Correlated_Comparison.pdf', format='pdf', bbox_inches = 'tight')
bss_plot.show()

# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

# %%
def create_summary_table(df):
    """
    Groups by Model and computes Mean ± Std.
    Explodes the SNR list to calculate true component-level statistics.
    """
    # 1. Calculate Mean Component SNR for each row
    # (Extracting from your list of lists format)
    df['mSNR'] = df['SNR'].apply(lambda x: np.mean(x[0]) if isinstance(x, list) else np.nan)

    # 2. Aggregate
    summary = df.groupby('Model').agg({
        'SINR': ['mean', 'std'],
        'mSNR': ['mean', 'std'],
        'execution_time': ['mean', 'std']
    })

    # 3. Format for Paper
    final = pd.DataFrame(index=summary.index)
    final['SINR (dB)'] = summary.apply(lambda x: f"{x[('SINR', 'mean')]:.2f} ± {x[('SINR', 'std')]:.2f}", axis=1)
    final['mSNR (dB)'] = summary.apply(lambda x: f"{x[('mSNR', 'mean')]:.2f} ± {x[('mSNR', 'std')]:.2f}", axis=1)
    final['Time (s)'] = summary.apply(lambda x: f"{x[('execution_time', 'mean')]:.2f} ± {x[('execution_time', 'std')]:.2f}", axis=1)

    return final

# %% [markdown]
# # 5 by 3 Mixing Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_nnantisparse_5by3_results.pkl")
df_predictiveBSS.tail()
# Out:
#     seed                Model       SINR  \
# 25  2500  PredictiveDecorrBSS  21.907302
# 26  2600  PredictiveDecorrBSS  22.486163
# 27  2700  PredictiveDecorrBSS  22.670263
# 28  2800  PredictiveDecorrBSS  22.438459
# 29  2900  PredictiveDecorrBSS  19.851970
#
#                                                   SNR     SNRinp  \
# 25  [[21.32727846008525, 24.040545338662813, 21.02...  29.976451
# 26  [[22.287624882791718, 22.240234083976315, 23.0...  30.007836
# 27  [[24.464211601260615, 22.354612376423653, 21.7...  29.977875
# 28  [[22.885376223885533, 23.478328036144035, 21.3...  29.989056
# 29  [[21.952586383668773, 17.62053030847202, 21.54...  29.991564
#
#     execution_time
# 25       10.439308
# 26       10.438279
# 27       10.385037
# 28       10.391474
# 29       10.478789

# %%
create_summary_table(df_predictiveBSS)
# Out:
#                         SINR (dB)     mSNR (dB)      Time (s)
# Model
# PredictiveDecorrBSS  21.96 ± 1.15  22.16 ± 0.91  11.11 ± 2.87

# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # 10 by 5 Mixing with Correlated Sources

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_correlated_nnantisparse_10by5_results.pkl")
df_predictiveBSS.tail()
# Out:
#                           Model  seed  rho       SINR  \
# 1645        PredictiveDecorrBSS  2901  0.5  22.438325
# 1646              CorInfoMaxBSS  2901  0.5  23.619378
# 1647                ICA_InfoMax  2901  0.5   8.060364
# 1648                    LDMIBSS  2901  0.5  33.140378
# 1649  PredictiveDecorrBSSSimple  2901  0.5   9.265837
#
#                                                     SNR  SNRinp  \
# 1645  [[21.862322817799644, 22.982028061375388, 22.6...      30
# 1646  [[23.698907244397628, 24.50890826707468, 23.53...      30
# 1647  [[15.82810394864476, 6.340787009675229, 6.3479...      30
# 1648  [[32.188689278542796, 32.59689340791189, 33.47...      30
# 1649  [[26.43382998758787, 26.318282498555604, 5.611...      30
#
#       execution_time
# 1645        3.651986
# 1646        2.003944
# 1647        2.487334
# 1648        6.427668
# 1649        3.192733

# %%
summary_df = create_summary_table(df_predictiveBSS)
summary_df
# Out:
#                                           SINR (dB)     mSNR (dB)     Time (s)
# Model                     rho  SNRinp
# CorInfoMaxBSS             0.00 30      25.45 ± 0.45  25.88 ± 0.40  1.73 ± 0.04
# ICA_InfoMax               0.00 30      25.31 ± 0.63  26.05 ± 0.51  2.44 ± 0.05
# LDMIBSS                   0.00 30      28.89 ± 0.86  30.05 ± 0.59  6.19 ± 0.21
# PredictiveDecorrBSS       0.00 30      25.24 ± 1.52  26.14 ± 0.63  2.70 ± 0.23
# PredictiveDecorrBSSSimple 0.00 30      -2.15 ± 0.53  15.25 ± 1.32  2.70 ± 0.08
# CorInfoMaxBSS             0.05 30      25.39 ± 0.48  25.79 ± 0.43  1.85 ± 0.11
# ICA_InfoMax               0.05 30      23.57 ± 0.47  23.93 ± 0.38  2.41 ± 0.04
# LDMIBSS                   0.05 30      28.95 ± 0.89  30.15 ± 0.59  6.01 ± 0.06
# PredictiveDecorrBSS       0.05 30      25.02 ± 1.56  26.02 ± 0.58  2.95 ± 0.19
# PredictiveDecorrBSSSimple 0.05 30       6.15 ± 0.53  15.26 ± 1.29  3.01 ± 0.17
# CorInfoMaxBSS             0.10 30      25.26 ± 0.42  25.64 ± 0.37  1.70 ± 0.03
# ICA_InfoMax               0.10 30      21.05 ± 0.28  21.18 ± 0.24  2.38 ± 0.02
# LDMIBSS                   0.10 30      29.07 ± 0.92  30.25 ± 0.62  6.03 ± 0.04
# PredictiveDecorrBSS       0.10 30      24.67 ± 1.31  25.62 ± 0.55  2.66 ± 0.07
# PredictiveDecorrBSSSimple 0.10 30       6.09 ± 0.46  14.77 ± 1.16  2.75 ± 0.08
# CorInfoMaxBSS             0.15 30      25.13 ± 0.42  25.51 ± 0.37  1.73 ± 0.02
# ICA_InfoMax               0.15 30      19.08 ± 0.19  19.15 ± 0.16  2.40 ± 0.02
# LDMIBSS                   0.15 30      29.12 ± 0.92  30.31 ± 0.62  6.06 ± 0.05
# PredictiveDecorrBSS       0.15 30      24.64 ± 1.02  25.40 ± 0.43  2.75 ± 0.14
# PredictiveDecorrBSSSimple 0.15 30       6.40 ± 0.53  15.03 ± 1.25  2.94 ± 0.22
# CorInfoMaxBSS             0.20 30      24.64 ± 0.99  25.24 ± 0.57  1.87 ± 0.13
# ICA_InfoMax               0.20 30      17.25 ± 0.64  17.39 ± 0.44  2.41 ± 0.04
# LDMIBSS                   0.20 30      29.16 ± 0.91  30.42 ± 0.61  6.10 ± 0.06
# PredictiveDecorrBSS       0.20 30      24.92 ± 0.76  25.33 ± 0.37  2.91 ± 0.23
# PredictiveDecorrBSSSimple 0.20 30       6.57 ± 0.47  15.14 ± 1.16  3.08 ± 0.20
# CorInfoMaxBSS             0.25 30      24.88 ± 0.40  25.22 ± 0.35  1.83 ± 0.08
# ICA_InfoMax               0.25 30      16.05 ± 0.55  16.17 ± 0.35  2.40 ± 0.03
# LDMIBSS                   0.25 30      29.29 ± 0.93  30.53 ± 0.63  6.08 ± 0.04
# PredictiveDecorrBSS       0.25 30      24.55 ± 0.39  24.83 ± 0.29  2.74 ± 0.08
# PredictiveDecorrBSSSimple 0.25 30       6.66 ± 0.47  14.76 ± 1.17  2.85 ± 0.10
# CorInfoMaxBSS             0.30 30      24.68 ± 0.41  25.03 ± 0.34  1.80 ± 0.06
# ICA_InfoMax               0.30 30      15.00 ± 0.48  15.12 ± 0.27  2.39 ± 0.01
# LDMIBSS                   0.30 30      29.38 ± 0.96  30.68 ± 0.62  6.09 ± 0.03
# PredictiveDecorrBSS       0.30 30      23.96 ± 0.87  24.35 ± 0.50  2.87 ± 0.19
# PredictiveDecorrBSSSimple 0.30 30       7.15 ± 0.47  15.47 ± 1.13  2.90 ± 0.17
# CorInfoMaxBSS             0.35 30      24.38 ± 0.39  24.71 ± 0.33  1.74 ± 0.03
# ICA_InfoMax               0.35 30      13.78 ± 0.80  14.03 ± 0.47  2.41 ± 0.04
# LDMIBSS                   0.35 30      29.53 ± 0.95  30.80 ± 0.63  6.11 ± 0.06
# PredictiveDecorrBSS       0.35 30      23.42 ± 0.90  23.88 ± 0.35  2.68 ± 0.06
# PredictiveDecorrBSSSimple 0.35 30       7.46 ± 0.59  15.39 ± 1.30  2.87 ± 0.14
# CorInfoMaxBSS             0.40 30      24.26 ± 0.38  24.54 ± 0.34  1.85 ± 0.08
# ICA_InfoMax               0.40 30      12.33 ± 1.04  12.95 ± 0.52  2.41 ± 0.03
# LDMIBSS                   0.40 30      29.68 ± 0.95  30.98 ± 0.61  6.09 ± 0.05
# PredictiveDecorrBSS       0.40 30      23.42 ± 0.25  23.59 ± 0.23  2.89 ± 0.15
# PredictiveDecorrBSSSimple 0.40 30       7.57 ± 0.46  15.31 ± 1.11  2.96 ± 0.19
# CorInfoMaxBSS             0.45 30      23.95 ± 0.41  24.19 ± 0.37  1.75 ± 0.02
# ICA_InfoMax               0.45 30      11.10 ± 0.85  12.02 ± 0.38  2.43 ± 0.04
# LDMIBSS                   0.45 30      29.86 ± 0.96  31.15 ± 0.62  6.17 ± 0.08
# PredictiveDecorrBSS       0.45 30      22.94 ± 0.26  23.09 ± 0.23  2.68 ± 0.07
# PredictiveDecorrBSSSimple 0.45 30       7.78 ± 0.44  15.10 ± 1.02  2.74 ± 0.06
# CorInfoMaxBSS             0.50 30      23.41 ± 0.62  23.83 ± 0.42  1.83 ± 0.09
# ICA_InfoMax               0.50 30       8.04 ± 0.15  10.16 ± 0.09  2.42 ± 0.03
# LDMIBSS                   0.50 30      30.02 ± 0.94  31.27 ± 0.60  6.18 ± 0.07
# PredictiveDecorrBSS       0.50 30      21.96 ± 0.89  22.27 ± 0.57  2.80 ± 0.12
# PredictiveDecorrBSSSimple 0.50 30       8.37 ± 0.53  15.66 ± 1.14  2.85 ± 0.11

# %%
plot_title = "Correlated Nonnegative Antisparse Source Separation - mSNR Results"
bss_plot = plot_snr_performance(summary_df, title = plot_title)
# plt.savefig('Figures/NNAntisparse_Correlated_Comparison.pdf', format='pdf', bbox_inches = 'tight')
bss_plot.show()

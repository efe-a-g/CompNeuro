# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

# %%
def create_summary_table(df):
    """
    Groups by Model and computes Mean ± Std.
    Explodes the SNR list to calculate true component-level statistics.
    """
    # 1. Calculate Mean Component SNR for each row
    # (Extracting from your list of lists format)
    df['mSNR'] = df['SNR'].apply(lambda x: np.mean(x[0]) if isinstance(x, list) else np.nan)

    # 2. Aggregate
    summary = df.groupby('Model').agg({
        'SINR': ['mean', 'std'],
        'mSNR': ['mean', 'std'],
        'execution_time': ['mean', 'std']
    })

    # 3. Format for Paper
    final = pd.DataFrame(index=summary.index)
    final['SINR (dB)'] = summary.apply(lambda x: f"{x[('SINR', 'mean')]:.2f} ± {x[('SINR', 'std')]:.2f}", axis=1)
    final['mSNR (dB)'] = summary.apply(lambda x: f"{x[('mSNR', 'mean')]:.2f} ± {x[('mSNR', 'std')]:.2f}", axis=1)
    final['Time (s)'] = summary.apply(lambda x: f"{x[('execution_time', 'mean')]:.2f} ± {x[('execution_time', 'std')]:.2f}", axis=1)

    return final

# %% [markdown]
# # 10 by 5 Mixing Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_nnsparse_10by5_results.pkl")
df_predictiveBSS
# Out:
#     seed                Model       SINR  \
# 0      1  PredictiveDecorrBSS  25.726566
# 1    101  PredictiveDecorrBSS  25.985620
# 2    201  PredictiveDecorrBSS  26.137867
# 3    301  PredictiveDecorrBSS  24.202053
# 4    401  PredictiveDecorrBSS  27.377149
# 5    501  PredictiveDecorrBSS  27.109006
# 6    601  PredictiveDecorrBSS  26.373825
# 7    701  PredictiveDecorrBSS  25.661726
# 8    801  PredictiveDecorrBSS  26.166655
# 9    901  PredictiveDecorrBSS  25.148611
# 10  1001  PredictiveDecorrBSS  25.679908
# 11  1101  PredictiveDecorrBSS  26.493750
# 12  1201  PredictiveDecorrBSS  24.175850
# 13  1301  PredictiveDecorrBSS  25.366274
# 14  1401  PredictiveDecorrBSS  25.657836
# 15  1501  PredictiveDecorrBSS  26.217500
# 16  1601  PredictiveDecorrBSS  26.467029
# 17  1701  PredictiveDecorrBSS  26.801625
# 18  1801  PredictiveDecorrBSS  25.210350
# 19  1901  PredictiveDecorrBSS  26.286000
# 20  2001  PredictiveDecorrBSS  24.417777
# 21  2101  PredictiveDecorrBSS  26.323936
# 22  2201  PredictiveDecorrBSS  26.414926
# 23  2301  PredictiveDecorrBSS  25.763879
# 24  2401  PredictiveDecorrBSS  25.645382
# 25  2501  PredictiveDecorrBSS  25.972565
# 26  2601  PredictiveDecorrBSS  23.492266
# 27  2701  PredictiveDecorrBSS  26.012109
# 28  2801  PredictiveDecorrBSS  26.079715
# 29  2901  PredictiveDecorrBSS  25.835641
#
#                                                   SNR     SNRinp  \
# 0   [[27.586179824986182, 29.549199660299223, 23.8...  30.006600
# 1   [[23.704878352822544, 28.949624031654054, 26.8...  29.992219
# 2   [[26.404640752045005, 25.37733362230759, 26.88...  30.004610
# 3   [[28.428175376748747, 25.563918207171533, 26.1...  29.992473
# 4   [[26.51970607774009, 27.821540351402298, 28.59...  30.005279
# 5   [[26.36674963708508, 26.55538914063009, 27.449...  30.002769
# 6   [[26.474897812912104, 26.22280966055719, 25.64...  30.008074
# 7   [[27.258373058165684, 25.67654886618434, 25.60...  30.007288
# 8   [[26.69949570590646, 25.03997473842583, 27.888...  30.000213
# 9   [[23.922291117490133, 25.71841426609108, 23.70...  29.993325
# 10  [[25.88709758408633, 25.047688833944953, 26.58...  30.005251
# 11  [[28.476470399559105, 26.198909775370257, 26.9...  30.000475
# 12  [[27.325551181772923, 26.09891105250454, 25.41...  29.996279
# 13  [[24.010231414813987, 25.48694915997117, 26.71...  29.994121
# 14  [[25.63312163571906, 25.092567220387334, 25.61...  30.006565
# 15  [[29.635335141138736, 24.428259233829493, 27.6...  29.993042
# 16  [[25.636590248452343, 28.481716463499357, 27.1...  30.002982
# 17  [[26.667946211570303, 27.65813763995421, 29.07...  30.001473
# 18  [[27.235965641327486, 23.65889195239648, 26.33...  29.993123
# 19  [[26.116454251930023, 27.117416813096927, 26.7...  30.004283
# 20  [[23.462890134431298, 22.927274914528315, 25.2...  30.001068
# 21  [[27.146491514589, 27.275312021006883, 24.8425...  29.995944
# 22  [[26.23871824979876, 28.190423154404378, 25.69...  30.001245
# 23  [[26.586079985183424, 25.857012712088363, 24.5...  30.008167
# 24  [[27.352542174189153, 26.49264186007082, 24.73...  29.996880
# 25  [[26.068115662294574, 27.843402581668272, 26.1...  30.000576
# 26  [[23.97779205999669, 27.170391407236036, 25.05...  30.006074
# 27  [[27.10347954739528, 26.25033266802328, 25.731...  30.006581
# 28  [[25.731584513945272, 26.137970571674465, 25.3...  29.988372
# 29  [[26.21078027564502, 25.083630108640705, 26.31...  30.000332
#
#     execution_time
# 0        38.384656
# 1        22.682721
# 2        22.961503
# 3        22.156294
# 4        23.402423
# 5        23.222788
# 6        22.778241
# 7        22.599714
# 8        22.864032
# 9        22.423637
# 10       22.393164
# 11       23.155979
# 12       22.773270
# 13       24.234081
# 14       25.692259
# 15       27.213508
# 16       28.252046
# 17       29.600548
# 18       29.444663
# 19       30.307564
# 20       28.324842
# 21       25.575186
# 22       26.030706
# 23       26.041896
# 24       26.275066
# 25       26.482694
# 26       24.898184
# 27       26.252514
# 28       26.339560
# 29       25.298058

# %%
create_summary_table(df_predictiveBSS)
# Out:
#                         SINR (dB)     mSNR (dB)      Time (s)
# Model
# PredictiveDecorrBSS  25.81 ± 0.86  26.01 ± 0.75  25.60 ± 3.40

# %%
df_predictiveBSS["SINR"].mean()
# Out:
# np.float64(25.80677988011612)

# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # 10 by 5 Mixing Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_noisy_nnsparse_10by5_results.pkl")
df_predictiveBSS.tail()
# Out:
#                    Model  seed      SINR  \
# 451           CorInfoMax     1  5.450569
# 452              LDMIBSS     1  6.295997
# 453  PredictiveDecorrBSS   101  6.390797
# 454           CorInfoMax   101  6.008118
# 455              LDMIBSS   101  6.065629
#
#                                                    SNR  SNRinp  execution_time
# 451  [[4.601983283975658, 10.63406412122982, 4.8897...     5.0       27.103750
# 452  [[5.861428467202395, 10.756163444805754, 5.569...     5.0       34.695795
# 453  [[3.8750879164518266, 7.82467346801859, 6.7130...     5.0        8.134695
# 454  [[3.562853223398643, 7.17817355729194, 6.32340...     5.0       25.934736
# 455  [[3.6611073620539325, 7.410880881831962, 6.315...     5.0       34.184960

# %%
create_summary_table(df_predictiveBSS)
# Out:
#                                SINR (dB)     mSNR (dB)      Time (s)
# Model               SNRinp
# CorInfoMax          5.0      5.73 ± 3.54   6.13 ± 2.17  26.52 ± 7.43
# LDMIBSS             5.0      6.18 ± 1.46   6.52 ± 2.06  34.44 ± 3.25
# PredictiveDecorrBSS 5.0      6.38 ± 0.09   6.74 ± 0.35   7.86 ± 3.44
# CorInfoMax          10.0    10.15 ± 0.39  10.52 ± 0.30  26.72 ± 0.30
# LDMIBSS             10.0    10.13 ± 0.48  10.52 ± 0.38  34.78 ± 0.40
# PredictiveDecorrBSS 10.0    10.76 ± 0.51  11.15 ± 0.37   8.52 ± 0.09
# CorInfoMax          15.0    14.73 ± 0.52  15.18 ± 0.41  27.11 ± 0.58
# LDMIBSS             15.0    14.74 ± 0.57  15.18 ± 0.45  34.95 ± 0.61
# PredictiveDecorrBSS 15.0    15.26 ± 0.57  15.69 ± 0.44   8.88 ± 0.18
# CorInfoMax          20.0    19.47 ± 0.56  19.91 ± 0.45  29.01 ± 0.69
# LDMIBSS             20.0    19.44 ± 0.76  20.00 ± 0.55  36.01 ± 1.80
# PredictiveDecorrBSS 20.0    19.66 ± 0.70  20.15 ± 0.49   9.50 ± 0.27
# CorInfoMax          25.0    23.10 ± 0.42  23.42 ± 0.35  26.02 ± 0.14
# LDMIBSS             25.0    24.08 ± 1.04  24.79 ± 0.67  34.99 ± 0.40
# PredictiveDecorrBSS 25.0    23.92 ± 0.89  24.47 ± 0.54   8.98 ± 0.06
# CorInfoMax          30.0    26.29 ± 0.34  26.54 ± 0.31  28.86 ± 1.25
# LDMIBSS             30.0    28.57 ± 1.43  29.50 ± 0.82  35.39 ± 1.23
# PredictiveDecorrBSS 30.0    27.62 ± 1.32  28.29 ± 0.74  10.68 ± 0.86

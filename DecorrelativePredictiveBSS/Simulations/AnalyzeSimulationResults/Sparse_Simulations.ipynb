# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # 10 by 5 Mixing with Noisy Inputs Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_noisy_sparse_10by5_results.pkl")
df_predictiveBSS.tail()
# Out:
#                    Model  seed      SINR  \
# 355              LDMIBSS  2700  7.354188
# 356  PredictiveDecorrBSS  2800  7.350307
# 357              LDMIBSS  2800  7.193269
# 358  PredictiveDecorrBSS  2900  6.261998
# 359              LDMIBSS  2900  6.082842
#
#                                                    SNR  SNRinp  execution_time
# 355  [[5.862532368493703, 6.715618218160982, 8.1849...     5.0       25.574220
# 356  [[6.040819652770422, 7.115446040397955, 7.1483...     5.0       14.069972
# 357  [[5.967269458752391, 7.02378073708252, 6.92827...     5.0       25.440057
# 358  [[7.047327670894894, 6.598799490221987, 4.0769...     5.0       13.399420
# 359  [[6.9420235074695205, 6.465499220245125, 3.838...     5.0       24.111703

# %%
summary_df = create_summary_table(df_predictiveBSS)
summary_df
# Out:
#                                SINR (dB)     mSNR (dB)      Time (s)
# Model               SNRinp
# LDMIBSS             5.0      6.73 ± 0.73   6.99 ± 0.62  25.43 ± 0.27
# PredictiveDecorrBSS 5.0      6.92 ± 0.70   7.19 ± 0.58  14.71 ± 1.01
# LDMIBSS             10.0    10.67 ± 1.04  11.02 ± 0.89  24.95 ± 0.61
# PredictiveDecorrBSS 10.0    10.89 ± 1.02  11.26 ± 0.86  15.51 ± 1.04
# LDMIBSS             15.0    15.15 ± 1.27  15.57 ± 1.09  25.76 ± 0.84
# PredictiveDecorrBSS 15.0    15.40 ± 1.24  15.83 ± 1.04  16.00 ± 0.78
# LDMIBSS             20.0    19.97 ± 1.37  20.41 ± 1.18  25.16 ± 0.87
# PredictiveDecorrBSS 20.0    19.90 ± 1.34  20.30 ± 1.16  15.69 ± 0.41
# LDMIBSS             25.0    24.91 ± 1.39  25.37 ± 1.17  25.06 ± 0.62
# PredictiveDecorrBSS 25.0    23.50 ± 1.18  23.74 ± 1.05  16.77 ± 1.97
# LDMIBSS             30.0    29.84 ± 1.40  30.30 ± 1.18  25.79 ± 2.43
# PredictiveDecorrBSS 30.0    26.76 ± 0.85  26.93 ± 0.77  17.58 ± 3.70

# %%
plot_title = "Noisy Sparse Source Separation - mSNR Results"
bss_plot = plot_snr_performance(summary_df, 'SNRinp', title = plot_title)
plt.savefig('Figures/Sparse_Noisy_Comparison.pdf', format='pdf', bbox_inches = 'tight')
bss_plot.show()

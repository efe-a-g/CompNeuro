# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # 10 by 5 Mixing with Noisy Inputs Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_noisy_sparse_10by5_results.pkl")
df_predictiveBSS.tail()
# Out:
#                          Model  seed      SINR  \
# 715  PredictiveDecorrBSSSimple  2800  7.338320
# 716        PredictiveDecorrBSS  2900  6.261998
# 717              CorInfoMaxBSS  2900  4.088195
# 718                    LDMIBSS  2900  6.086076
# 719  PredictiveDecorrBSSSimple  2900  6.290331
#
#                                                    SNR  SNRinp  execution_time
# 715  [[6.026419114036131, 7.10682437370703, 7.13088...     5.0        4.971789
# 716  [[7.047327670894894, 6.598799490221987, 4.0769...     5.0        5.074150
# 717  [[6.776175717036742, 5.591330267312187, 0.7152...     5.0        8.981754
# 718  [[6.952846968612349, 6.460951862804054, 3.8458...     5.0        9.474732
# 719  [[7.0229238117198065, 6.59700516305183, 4.1776...     5.0        4.914653

# %%
summary_df = create_summary_table(df_predictiveBSS)
summary_df
# Out:
#                                      SINR (dB)     mSNR (dB)      Time (s)
# Model                     SNRinp
# CorInfoMaxBSS             5.0      6.27 ± 0.44   6.65 ± 0.34   9.25 ± 0.22
# LDMIBSS                   5.0      6.73 ± 0.27   6.99 ± 0.23   9.55 ± 0.10
# PredictiveDecorrBSS       5.0      6.92 ± 0.26   7.19 ± 0.22   5.25 ± 0.17
# PredictiveDecorrBSSSimple 5.0      6.93 ± 0.26   7.19 ± 0.22   5.03 ± 0.08
# CorInfoMaxBSS             10.0     9.21 ± 0.72   9.62 ± 0.58   9.44 ± 0.14
# LDMIBSS                   10.0    10.67 ± 0.39  11.01 ± 0.34   9.36 ± 0.16
# PredictiveDecorrBSS       10.0    10.89 ± 0.38  11.26 ± 0.32   5.84 ± 0.21
# PredictiveDecorrBSSSimple 10.0    10.87 ± 0.38  11.25 ± 0.32   5.53 ± 0.09
# CorInfoMaxBSS             15.0    12.81 ± 0.54  13.03 ± 0.51  10.24 ± 0.58
# LDMIBSS                   15.0    15.15 ± 0.48  15.56 ± 0.41   9.49 ± 0.11
# PredictiveDecorrBSS       15.0    15.40 ± 0.46  15.83 ± 0.39   6.59 ± 0.54
# PredictiveDecorrBSSSimple 15.0    15.38 ± 0.47  15.82 ± 0.39   6.75 ± 0.68
# CorInfoMaxBSS             20.0    16.10 ± 0.45  16.26 ± 0.42  10.79 ± 0.94
# LDMIBSS                   20.0    19.97 ± 0.51  20.42 ± 0.44   9.32 ± 0.09
# PredictiveDecorrBSS       20.0    19.90 ± 0.50  20.30 ± 0.43   6.61 ± 0.39
# PredictiveDecorrBSSSimple 20.0    19.90 ± 0.50  20.31 ± 0.42   6.49 ± 0.50
# CorInfoMaxBSS             25.0    19.79 ± 0.73  20.16 ± 0.48  10.83 ± 0.05
# LDMIBSS                   25.0    24.89 ± 0.52  25.35 ± 0.44   9.21 ± 0.05
# PredictiveDecorrBSS       25.0    23.50 ± 0.44  23.74 ± 0.39   6.47 ± 0.45
# PredictiveDecorrBSSSimple 25.0    23.51 ± 0.43  23.77 ± 0.38   6.41 ± 0.55
# CorInfoMaxBSS             30.0    23.89 ± 1.25  24.59 ± 0.69  11.52 ± 0.19
# LDMIBSS                   30.0    29.83 ± 0.52  30.29 ± 0.44   9.56 ± 0.19
# PredictiveDecorrBSS       30.0    26.76 ± 0.32  26.93 ± 0.29   6.46 ± 0.37
# PredictiveDecorrBSSSimple 30.0    26.10 ± 1.38  26.58 ± 0.77   6.06 ± 0.22

# %%
plot_title = "Noisy Sparse Source Separation - mSNR Results"
bss_plot = plot_snr_performance(summary_df, 'SNRinp', title = plot_title)
plt.savefig('Figures/Sparse_Noisy_Comparison.pdf', format='pdf', bbox_inches = 'tight')
bss_plot.show()

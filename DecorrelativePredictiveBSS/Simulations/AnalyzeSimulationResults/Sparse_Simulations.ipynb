# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

# %%
def create_summary_table(df):
    """
    Groups by Model and computes Mean ± Std.
    Explodes the SNR list to calculate true component-level statistics.
    """
    # 1. Calculate Mean Component SNR for each row
    # (Extracting from your list of lists format)
    df['mSNR'] = df['SNR'].apply(lambda x: np.mean(x[0]) if isinstance(x, list) else np.nan)

    # 2. Aggregate
    summary = df.groupby('Model').agg({
        'SINR': ['mean', 'std'],
        'mSNR': ['mean', 'std'],
        'execution_time': ['mean', 'std']
    })

    # 3. Format for Paper
    final = pd.DataFrame(index=summary.index)
    final['SINR (dB)'] = summary.apply(lambda x: f"{x[('SINR', 'mean')]:.2f} ± {x[('SINR', 'std')]:.2f}", axis=1)
    final['mSNR (dB)'] = summary.apply(lambda x: f"{x[('mSNR', 'mean')]:.2f} ± {x[('mSNR', 'std')]:.2f}", axis=1)
    final['Time (s)'] = summary.apply(lambda x: f"{x[('execution_time', 'mean')]:.2f} ± {x[('execution_time', 'std')]:.2f}", axis=1)

    return final

# %% [markdown]
# # 5 by 3 Mixing Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_sparse_5by3_results.pkl")
df_predictiveBSS.tail()
# Out:
#     seed                Model       SINR  \
# 25  2500  PredictiveDecorrBSS  28.823760
# 26  2600  PredictiveDecorrBSS  31.486714
# 27  2700  PredictiveDecorrBSS  30.709467
# 28  2800  PredictiveDecorrBSS  31.097521
# 29  2900  PredictiveDecorrBSS  22.641969
#
#                                                   SNR     SNRinp  \
# 25  [[25.96771935197841, 31.113875033045733, 32.00...  29.982072
# 26  [[32.58000369097425, 32.05027782797715, 30.210...  30.011181
# 27  [[28.695294854778982, 33.835870959993954, 31.0...  29.974843
# 28  [[31.63782526051254, 31.523614838681254, 30.27...  29.990894
# 29  [[27.688166364360814, 18.75562551560456, 29.27...  29.997374
#
#     execution_time
# 25       19.161879
# 26       19.210929
# 27       19.121241
# 28       19.167346
# 29       18.844918

# %%
create_summary_table(df_predictiveBSS)
# Out:
#                         SINR (dB)     mSNR (dB)      Time (s)
# Model
# PredictiveDecorrBSS  29.00 ± 2.78  29.52 ± 2.47  16.42 ± 3.45

# %%
df_predictiveBSS["SINR"].mean()
# Out:
# np.float64(29.000414161460096)

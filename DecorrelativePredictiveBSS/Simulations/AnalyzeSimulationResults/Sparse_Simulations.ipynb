# %%
import sys
sys.path.insert(0, '../Results')
sys.path.insert(0, '../../src')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import os

from python_utils.visualization_utils import create_summary_table, plot_snr_performance

# %%
if not os.path.exists("Figures"):
    os.mkdir("Figures")

# %% [markdown]
# # 10 by 5 Mixing with Noisy Inputs Results

# %%
df_predictiveBSS = pd.read_pickle(r"../Results/predictive_bss_noisy_sparse_10by5_results.pkl")
df_predictiveBSS.tail()
# Out:
#                          Model  seed      SINR  \
# 715  PredictiveDecorrBSSSimple  2800  7.338318
# 716        PredictiveDecorrBSS  2900  6.261998
# 717              CorInfoMaxBSS  2900  6.200473
# 718                    LDMIBSS  2900  6.082588
# 719  PredictiveDecorrBSSSimple  2900  6.290328
#
#                                                    SNR  SNRinp  execution_time
# 715  [[6.026421155276067, 7.106822282003976, 7.1308...     5.0        4.891791
# 716  [[7.047327670894894, 6.598799490221987, 4.0769...     5.0        5.322228
# 717  [[7.01898051796575, 6.43851758860464, 4.080049...     5.0       12.260648
# 718  [[6.921702534603852, 6.494447726197396, 3.8222...     5.0        8.913645
# 719  [[7.022919479293018, 6.597000329794277, 4.1776...     5.0        4.810065

# %%
summary_df = create_summary_table(df_predictiveBSS)
summary_df
# Out:
#                                      SINR (dB)     mSNR (dB)      Time (s)
# Model                     SNRinp
# CorInfoMaxBSS             5.0      6.76 ± 0.25   7.02 ± 0.21  12.62 ± 0.53
# LDMIBSS                   5.0      6.73 ± 0.27   6.99 ± 0.23   8.99 ± 0.07
# PredictiveDecorrBSS       5.0      6.92 ± 0.26   7.19 ± 0.22   5.29 ± 0.23
# PredictiveDecorrBSSSimple 5.0      6.93 ± 0.26   7.19 ± 0.22   5.04 ± 0.19
# CorInfoMaxBSS             10.0    10.71 ± 0.38  11.08 ± 0.32  12.57 ± 0.73
# LDMIBSS                   10.0    10.67 ± 0.39  11.02 ± 0.34   8.98 ± 0.12
# PredictiveDecorrBSS       10.0    10.89 ± 0.38  11.26 ± 0.32   6.56 ± 0.46
# PredictiveDecorrBSSSimple 10.0    10.87 ± 0.38  11.25 ± 0.32   6.50 ± 0.50
# CorInfoMaxBSS             15.0    15.16 ± 0.47  15.59 ± 0.39  12.21 ± 0.45
# LDMIBSS                   15.0    15.15 ± 0.47  15.56 ± 0.41   9.17 ± 0.11
# PredictiveDecorrBSS       15.0    15.40 ± 0.46  15.83 ± 0.39   6.02 ± 0.21
# PredictiveDecorrBSSSimple 15.0    15.38 ± 0.47  15.82 ± 0.39   5.68 ± 0.18
# CorInfoMaxBSS             20.0    19.63 ± 0.52  20.03 ± 0.45  14.43 ± 1.05
# LDMIBSS                   20.0    19.97 ± 0.51  20.41 ± 0.44   8.99 ± 0.06
# PredictiveDecorrBSS       20.0    19.90 ± 0.50  20.30 ± 0.43   6.44 ± 0.60
# PredictiveDecorrBSSSimple 20.0    19.90 ± 0.50  20.32 ± 0.43   5.97 ± 0.24
# CorInfoMaxBSS             25.0    23.52 ± 0.49  23.80 ± 0.43  16.50 ± 1.17
# LDMIBSS                   25.0    24.89 ± 0.52  25.35 ± 0.44   8.99 ± 0.08
# PredictiveDecorrBSS       25.0    23.50 ± 0.44  23.74 ± 0.39   6.33 ± 0.54
# PredictiveDecorrBSSSimple 25.0    22.91 ± 1.21  23.43 ± 0.72   6.00 ± 0.35
# CorInfoMaxBSS             30.0    27.17 ± 0.39  27.36 ± 0.34  18.57 ± 0.40
# LDMIBSS                   30.0    29.86 ± 0.51  30.31 ± 0.43   9.45 ± 0.25
# PredictiveDecorrBSS       30.0    26.76 ± 0.32  26.93 ± 0.29   6.21 ± 0.33
# PredictiveDecorrBSSSimple 30.0    26.11 ± 1.39  26.59 ± 0.77   5.72 ± 0.08

# %%
plot_title = "Noisy Sparse Source Separation - mSNR Results"
bss_plot = plot_snr_performance(summary_df, 'SNRinp', title = plot_title)
plt.savefig('Figures/Sparse_Noisy_Comparison.pdf', format='pdf', bbox_inches = 'tight')
bss_plot.show()
